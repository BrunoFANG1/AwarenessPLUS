# %%
from bertopic import BERTopic
from bertopic.vectorizers import ClassTfidfTransformer
from sklearn.datasets import fetch_20newsgroups
import time

# Data
docs = fetch_20newsgroups(subset='all',  remove=('headers', 'footers', 'quotes'))['data']

time1 = time.time()

# Load and run model
# topic_model = BERTopic()
ctfidf_model = ClassTfidfTransformer()
topic_model = BERTopic(ctfidf_model=ctfidf_model)
topics, probs = topic_model.fit_transform(docs)

time2 = time.time()
print(time2-time1)
# Out:
# 29.46511745452881

# %%
# A Pandas Dataframe of all topic infos
topic_model.get_topic_info()

# A Pandas Dataframe of all document infos
topic_model.get_document_info(docs)
# Out:
#                                                 Document  Topic  \
# 0      \n\nI am sure some bashers of Pens fans are pr...      0
# 1      My brother is in the market for a high-perform...     -1
# 2      \n\n\n\n\tFinally you said what you dream abou...     -1
# 3      \nThink!\n\nIt's the SCSI card doing the DMA t...      3
# 4      1)    I have an old Jasmine drive which I cann...    110
# ...                                                  ...    ...
# 18841  DN> From: nyeda@cnsvax.uwec.edu (David Nye)\nD...     -1
# 18842  \nNot in isolated ground recepticles (usually ...    180
# 18843  I just installed a DX2-66 CPU in a clone mothe...     92
# 18844  \nWouldn't this require a hyper-sphere.  In 3-...     25
# 18845  After a tip from Gary Crum (crum@fcom.cc.utah....      7
#
#                                          Name  \
# 0                        0_game_team_games_he
# 1                             -1_to_the_is_of
# 2                             -1_to_the_is_of
# 3                     3_drive_scsi_drives_ide
# 4                 110_tape_backup_tapes_drive
# ...                                       ...
# 18841                         -1_to_the_is_of
# 18842  180_ground_grounding_conductor_neutral
# 18843                    92_fan_cpu_heat_sink
# 18844              25_den_polygon_points_xxxx
# 18845                 7_car_cars_mustang_ford
#
#                                           Representation  \
# 0      [game, team, games, he, players, season, hocke...
# 1         [to, the, is, of, and, it, you, in, that, for]
# 2         [to, the, is, of, and, it, you, in, that, for]
# 3      [drive, scsi, drives, ide, disk, controller, h...
# 4      [tape, backup, tapes, drive, wangdat, munroe, ...
# ...                                                  ...
# 18841     [to, the, is, of, and, it, you, in, that, for]
# 18842  [ground, grounding, conductor, neutral, wire, ...
# 18843  [fan, cpu, heat, sink, fans, cooling, chip, ho...
# 18844  [den, polygon, points, xxxx, algorithm, plane,...
# 18845  [car, cars, mustang, ford, engine, v8, convert...
#
#                                      Representative_Docs  \
# 0      [\nWales Conference, Adams Division, Semifinal...
# 1      [\nI'd like to field this one, if I may.  Alth...
# 2      [\nI'd like to field this one, if I may.  Alth...
# 3      [Thanks to all who responded to my original po...
# 4      [I have a Colorado Memory Systems Jumbo 250 ta...
# ...                                                  ...
# 18841  [\nI'd like to field this one, if I may.  Alth...
# 18842  [\nNot according to the NEC nor the CEC, as ex...
# 18843  [N(P>Just got a 66MHz 486DX2 system, and am co...
# 18844  [\nSorry!! :-)\n\nCall the four points A, B, C...
# 18845  [\n\n\n\nYou know, I'm a Ford fan, I must say,...
#
#                                              Top_n_words  Probability  \
# 0      game - team - games - he - players - season - ...     1.000000
# 1      to - the - is - of - and - it - you - in - tha...     0.000000
# 2      to - the - is - of - and - it - you - in - tha...     0.000000
# 3      drive - scsi - drives - ide - disk - controlle...     1.000000
# 4      tape - backup - tapes - drive - wangdat - munr...     0.675516
# ...                                                  ...          ...
# 18841  to - the - is - of - and - it - you - in - tha...     0.000000
# 18842  ground - grounding - conductor - neutral - wir...     0.562794
# 18843  fan - cpu - heat - sink - fans - cooling - chi...     1.000000
# 18844  den - polygon - points - xxxx - algorithm - pl...     0.575776
# 18845  car - cars - mustang - ford - engine - v8 - co...     0.610938
#
#        Representative_document
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False
# ...                        ...
# 18841                    False
# 18842                    False
# 18843                    False
# 18844                    False
# 18845                    False
#
# [18846 rows x 8 columns]

# %%
# Convert document info dataframe to np array 
# arr[][0] = documents
# arr[][1] = topics
docs_arr = topic_model.get_document_info(docs).to_numpy()

# Get all documents of a given topic, e.g., topic 0
docs_0 = []
for row in docs_arr: 
    if row[1] == 0:
        docs_0.append(row[0])
